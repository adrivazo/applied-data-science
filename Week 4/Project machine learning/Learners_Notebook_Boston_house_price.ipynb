# %% [markdown]
# # Project Linear Regression: Boston House Price Prediction
#
# # **Marks: 30**

# %% [markdown]
# Welcome to the project on Linear Regression. We will use the Boston house price data for the exercise.
#
# -------------------------------
# ## Problem Statement
# -------------------------------
#
# The problem on hand is to predict the housing prices of a town or a suburb based on the features of the locality provided to us. In the process, we need to identify the most important features in the dataset. We need to employ techniques of data preprocessing and build a linear regression model that predicts the prices for us.
#
# ----------------------------
# ## Data Information
# ---------------------------
#
# Each record in the database describes a Boston suburb or town. The data was drawn from the Boston Standard Metropolitan Statistical Area (SMSA) in 1970. Detailed attribute information can be found below-
#
# Attribute Information (in order):
# - **CRIM:**     per capita crime rate by town
# - **ZN:**       proportion of residential land zoned for lots over 25,000 sq.ft.
# - **INDUS:**    proportion of non-retail business acres per town
# - **CHAS:**     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# - **NOX:**      nitric oxides concentration (parts per 10 million)
# - **RM:**       average number of rooms per dwelling
# - **AGE:**     proportion of owner-occupied units built before 1940
# - **DIS:**      weighted distances to five Boston employment centers
# - **RAD:**      index of accessibility to radial highways
# - **TAX:**      full-value property-tax rate per 10,000 dollars
# - **PTRATIO:**  pupil-teacher ratio by town
# - **LSTAT:**    %lower status of the population
# - **MEDV:**     Median value of owner-occupied homes in 1000 dollars

# %% [markdown]
# ### Let us start by importing the required libraries

# %%
# import libraries for data manipulation
import pandas as pd
import numpy as np

# import libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.gofplots import ProbPlot

# import libraries for building linear regression model
from statsmodels.formula.api import ols
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression

# import library for preparing data
from sklearn.model_selection import train_test_split

# import library for data preprocessing
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Read the dataset

# %%
df = pd.read_csv("Boston.csv")
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    LSTAT  MEDV
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %% [markdown]
# **Observations**
# * The price of the house indicated by the variable MEDV is the target variable and the rest are the independent variables based on which we will predict house price.

# %% [markdown]
# ### Get information about the dataset using the info() method

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  LSTAT    506 non-null    float64
#  12  MEDV     506 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 51.5 KB

# %% [markdown]
# **Observations**
# * There are a total of 506 non-null observations in each of the columns. This indicates that there are no missing values in the data.
#
# * Every column in this dataset is numeric in nature.

# %% [markdown]
# ### Let's now check the summary statistics of this dataset

# %% [markdown]
# #### **Question 1:** Write the code to find the summary statistics and write your observations based on that. (1 Mark)

# %%
#write your code here
df.describe().T
# Out:
#          count        mean         std        min         25%        50%  \
# CRIM     506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# ZN       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# INDUS    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# CHAS     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# NOX      506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# RM       506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# AGE      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# DIS      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# RAD      506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# TAX      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# PTRATIO  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# LSTAT    506.0   12.653063    7.141062    1.73000    6.950000   11.36000
# MEDV     506.0   22.532806    9.197104    5.00000   17.025000   21.20000
#
#                 75%       max
# CRIM       3.677083   88.9762
# ZN        12.500000  100.0000
# INDUS     18.100000   27.7400
# CHAS       0.000000    1.0000
# NOX        0.624000    0.8710
# RM         6.623500    8.7800
# AGE       94.075000  100.0000
# DIS        5.188425   12.1265
# RAD       24.000000   24.0000
# TAX      666.000000  711.0000
# PTRATIO   20.200000   22.0000
# LSTAT     16.955000   37.9700
# MEDV      25.000000   50.0000

# %% [markdown]
# **Observations:____**
# * The proportion of residential land zoned for lots over 25,000 sq.ft.for most areas appears to be 0 suggesting most residential lots are <25k sq. ft
# * Mostly areas seem to have a low Crime rate, except for some really extreme outliers with high crime rate
# * Most suburbs are not by the river as suggested by CHAS 75th percentile being
# * The Boston area / suburbs have a lot of older properties and large properties (Average number of room range from 3.6-8.8, with a mean of 6)

# %% [markdown]
# Before performing the modeling, it is important to check the univariate distribution of the variables.

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# ### Check the distribution of the variables

# %%
# let's plot all the columns to look at their distributions
for i in df.columns:
    plt.figure(figsize=(7, 4))
    sns.histplot(data=df, x=i, kde = True)
    plt.show()

# %% [markdown]
# **Observations**
# * **The variables CRIM and ZN are positively skewed.** This suggests that most of the areas have lower crime rates and most residential plots are under the area of 25,000 sq. ft.
# * **The variable CHAS, with only 2 possible values 0 and 1, follows a binomial distribution**, and the majority of the houses are away from Charles river (CHAS = 0).
# * The distribution of the variable AGE suggests that many of the owner-occupied houses were built before 1940.
# * **The variable DIS** (average distances to five Boston employment centers) **has a nearly exponential distribution**, which indicates that most of the houses are closer to these employment centers.
# * **The variables TAX and RAD have a bimodal distribution.**, indicating that the tax rate is possibly higher for some properties which have a high index of accessibility to radial highways.
# * The dependent variable MEDV seems to be slightly right skewed.

# %% [markdown]
# As the dependent variable is sightly skewed, we will apply a **log transformation on the 'MEDV' column** and check the distribution of the transformed column.

# %%
df['MEDV_log'] = np.log(df['MEDV'])

# %%
sns.histplot(data=df, x='MEDV_log', kde = True)
# Out:
# <AxesSubplot:xlabel='MEDV_log', ylabel='Count'>

# %% [markdown]
# **Observations**
# * The log-transformed variable (**MEDV_log**) appears to have a **nearly normal distribution without skew**, and hence we can proceed.

# %% [markdown]
# Before creating the linear regression model, it is important to check the bivariate relationship between the variables. Let's check the same using the heatmap and scatterplot.

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# #### Let's check the correlation using the heatmap

# %% [markdown]
# ### **Question 2** (3 Marks):
# - **Write the code to plot the correlation heatmap between the variables (1 Mark)**
# - **Write your observations (2 Marks)**

# %%
plt.figure(figsize=(12,8))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(df.corr(),annot=True,fmt='.2f',cmap="YlGnBu" ) #write your code here
plt.show()

# %% [markdown]
# **Observations:______**
# * The dependent variable MEDV shows strong positive correlation with the number of avarage rooms RM which makes sense as one can imagine the value of a property increase with the number of rooms. MEDV is also positively correlated with ZN (so if other properties in the area are over 25k sq feet which could suggest more affluent neighborhoods with larger properties), with being close to the Charles, and DIS assuming people value having a easier commute to work.
# * MEDV is strongly negatively correlated with LSTAT, and also unsurprisingly negatively correlated with CRIM.
# * INDUS and NOX are positively correllated.
# * RAD and TAX are strongly positively correlated (which matches our previous observation that the tax rate is possibly higher for some properties which have a high index of accessibility to radial highways.)
# * RAD, TAX, PTRATIO AND LSTAT all show a positive correlation among each other.

# %% [markdown]
# Now, we will visualize the relationship between the pairs of features having significant correlations.

# %% [markdown]
# ### Visualizing the relationship between the features having significant correlations (> 0.7)

# %% [markdown]
# ### **Question 3** (6 Marks):
# - **Create a scatter plot to visualize the relationship between the features having significant correlations (>0.7) (3 Marks)**
# - **Write your observations from the plots (3 Marks)**

# %%
# scatterplot to visualize the relationship between NOX and INDUS
plt.figure(figsize=(6, 6))
sns.scatterplot(x='NOX', y='INDUS', hue='AGE', data=df);
plt.show()

# %% [markdown]
# **Observations:____**
# * The levels of NOX increases as the proportion of non-retail busines acres per town increase.
# * Could make sense assuming the non retail businesses are either industrial or even businesses where people need to commute to via car, and in general driving pollution levels higher
# * There seems to be a proportion of non-retail busines acres per town  (INDUS) that seems fixed AT AROUND 18. Could be due to zoning laws or measurements used to only be capped?

# %%
# scatterplot to visualize the relationship between AGE and NOX
plt.figure(figsize=(6, 6))
sns.scatterplot(x='AGE', y='NOX', data=df);
plt.show()

# %% [markdown]
# **Observations:____**
# * NOX levels seem to increase with the proportion of owner-occupied units built before 1940
# * Would be interesting to see if it's that older units pollute more, or is it that industrial areas have a higher proportion of older units or what other reasons could be driving this correlation

# %%
# scatterplot to visualize the relationship between DIS and NOX
plt.figure(figsize=(6, 6))
sns.scatterplot(x='DIS', y='NOX', hue='ZN', data=df);
plt.show()

# %% [markdown]
# **Observations:___**
# * Levels of NOX decrease with higher / further distance from the business centers which makes sense, assuming a higher DIS number means it's a more suburban area and a lower DIS means it's closer to an urban hub that could have several sources of pollution

# %%
# scatterplot to visualize the relationship between AGE and DIS
plt.figure(figsize=(6, 6))
sns.scatterplot(x = 'AGE', y = 'DIS', data = df)
plt.show()

# %% [markdown]
# **Observations:**
# * The distance of the houses to the Boston employment centers appears to decrease moderately as the the proportion of the old houses increase in the town. It is possible that the Boston employment centers are located in the established towns where proportion of owner-occupied units built prior to 1940 is comparatively high.

# %%
# scatterplot to visualize the relationship between AGE and INDUS
plt.figure(figsize=(6, 6))
sns.scatterplot(x = 'AGE', y = 'INDUS', data = df)
plt.show()

# %% [markdown]
# **Observations:**
# * No trend between the two variables is visible in the above plot.

# %%
# scatterplot to visulaize the relationship between RAD and TAX
plt.figure(figsize=(6, 6))
sns.scatterplot(x = 'RAD', y = 'TAX', data = df)
plt.show()

# %% [markdown]
# **Observations:**
# * The correlation between RAD and TAX is very high. But, no trend is visible between the two variables.
# This might be due to outliers.

# %% [markdown]
# Let's check the correlation after removing the outliers.

# %%
# remove the data corresponding to high tax rate
df1 = df[df['TAX'] < 600]
# import the required function
from scipy.stats import pearsonr
# calculate the correlation
print('The correlation between TAX and RAD is', pearsonr(df1['TAX'], df1['RAD'])[0])
# Out:
# The correlation between TAX and RAD is 0.249757313314292

# %% [markdown]
# So the high correlation between TAX and RAD is due to the outliers. The tax rate for some properties might be higher due to some other reason.

# %%
# scatterplot to visualize the relationship between INDUS and TAX
plt.figure(figsize=(6, 6))
sns.scatterplot(x = 'INDUS', y = 'TAX', data = df)
plt.show()

# %% [markdown]
# **Observations:**
# * The tax rate appears to increase with an increase in the proportion of non-retail business acres per town. This might be due to the reason that the variables TAX and INDUS are related with a third variable.

# %%
# scatterplot to visulaize the relationship between RM and MEDV
plt.figure(figsize=(6, 6))
sns.scatterplot(x = 'RM', y = 'MEDV', data = df)
plt.show()

# %% [markdown]
# **Observations:**
# * The price of the house seems to increase as the value of RM increases. This is expected as the price is generally higher for more rooms.
#
# * There are a few outliers in a horizontal line as the MEDV value seems to be capped at 50.

# %%
# scatterplot to visulaize the relationship between LSTAT and MEDV
plt.figure(figsize=(6, 6))
sns.scatterplot(x = 'LSTAT', y = 'MEDV', data = df)
plt.show()

# %% [markdown]
# **Observations:**
# * The price of the house tends to decrease with an increase in LSTAT. This is also possible as the house price is lower in areas where lower status people live.
# * There are few outliers and the data seems to be capped at 50.

# %% [markdown]
# We have seen that the variables LSTAT and RM have a linear relationship with the dependent variable MEDV. Also, there are significant relationships among a few independent variables, which is not desirable for a linear regression model. Let's first split the dataset.

# %% [markdown]
# ### Split the dataset
# Let's split the data into the dependent and independent variables and further split it into train and test set in a ratio of 70:30 for train and test set.

# %%
# separate the dependent and independent variable
Y = df['MEDV_log']
X = df.drop(columns = {'MEDV', 'MEDV_log'})

# add the intercept term
X = sm.add_constant(X)

# %%
# splitting the data in 70:30 ratio of train to test data
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.30 , random_state=1)

# %% [markdown]
# Next, we will check the multicollinearity in the train dataset.

# %% [markdown]
# ### Check for Multicollinearity
#
# We will use the Variance Inflation Factor (VIF), to check if there is multicollinearity in the data.
#
# Features having a VIF score > 5 will be dropped/treated till all the features have a VIF score < 5

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# function to check VIF
def checking_vif(train):
    vif = pd.DataFrame()
    vif["feature"] = train.columns

    # calculating VIF for each feature
    vif["VIF"] = [
        variance_inflation_factor(train.values, i) for i in range(len(train.columns))
    ]
    return vif


print(checking_vif(X_train))
# Out:
#     feature         VIF
# 0     const  535.372593
# 1      CRIM    1.924114
# 2        ZN    2.743574
# 3     INDUS    3.999538
# 4      CHAS    1.076564
# 5       NOX    4.396157
# 6        RM    1.860950
# 7       AGE    3.150170
# 8       DIS    4.355469
# 9       RAD    8.345247
# 10      TAX   10.191941
# 11  PTRATIO    1.943409
# 12    LSTAT    2.861881

# %% [markdown]
# **Observations:**
# * There are two variables with a high VIF - RAD and TAX. Let's remove TAX as it has the highest VIF values and check the multicollinearity again.

# %% [markdown]
# #### **Question 4:** Drop the column 'TAX' from the training data and check if multicollinearity is removed? (1 Mark)

# %%
X_train.head()
# Out:
#      const     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 13     1.0  0.62976   0.0   8.14     0  0.538  5.949  61.8  4.7075    4  307
# 61     1.0  0.17171  25.0   5.13     0  0.453  5.966  93.4  6.8185    8  284
# 377    1.0  9.82349   0.0  18.10     0  0.671  6.794  98.8  1.3580   24  666
# 39     1.0  0.02763  75.0   2.95     0  0.428  6.595  21.8  5.4011    3  252
# 365    1.0  4.55587   0.0  18.10     0  0.718  3.561  87.9  1.6132   24  666
#
#      PTRATIO  LSTAT
# 13      21.0   8.26
# 61      19.7  14.44
# 377     20.2  21.24
# 39      18.3   4.32
# 365     20.2   7.12

# %%
# create the model after dropping TAX
X_train = X_train.drop("TAX", axis=1)

# check for VIF
print(checking_vif(X_train))
# Out:
#     feature         VIF
# 0     const  532.025529
# 1      CRIM    1.923159
# 2        ZN    2.483399
# 3     INDUS    3.270983
# 4      CHAS    1.050708
# 5       NOX    4.361847
# 6        RM    1.857918
# 7       AGE    3.149005
# 8       DIS    4.333734
# 9       RAD    2.942862
# 10  PTRATIO    1.909750
# 11    LSTAT    2.860251

# %% [markdown]
# Now, we will create the linear regression model as the VIF is less than 5 for all the independent variables, and we can assume that multicollinearity has been removed between the variables.

# %% [markdown]
# #### **Question 5:** Write the code to create the linear regression model and print the model summary. Write your observations from the model. (3 Marks)

# %%
# here we are adding the intercept term
X_train = sm.add_constant(X_train)

# calling the OLS algorithm on the train features and target variable
model1 = sm.OLS(y_train, X_train)

# fitting the model
model1 = model1.fit()

# get the model summary
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               MEDV_log   R-squared:                       0.769
# Model:                            OLS   Adj. R-squared:                  0.761
# Method:                 Least Squares   F-statistic:                     103.3
# Date:                Mon, 14 Feb 2022   Prob (F-statistic):          1.40e-101
# Time:                        23:06:56   Log-Likelihood:                 76.596
# No. Observations:                 354   AIC:                            -129.2
# Df Residuals:                     342   BIC:                            -82.76
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.6324      0.243     19.057      0.000       4.154       5.111
# CRIM          -0.0128      0.002     -7.445      0.000      -0.016      -0.009
# ZN             0.0010      0.001      1.425      0.155      -0.000       0.002
# INDUS         -0.0004      0.003     -0.148      0.883      -0.006       0.005
# CHAS           0.1196      0.039      3.082      0.002       0.043       0.196
# NOX           -1.0598      0.187     -5.675      0.000      -1.427      -0.692
# RM             0.0532      0.021      2.560      0.011       0.012       0.094
# AGE            0.0003      0.001      0.461      0.645      -0.001       0.002
# DIS           -0.0503      0.010     -4.894      0.000      -0.071      -0.030
# RAD            0.0076      0.002      3.699      0.000       0.004       0.012
# PTRATIO       -0.0452      0.007     -6.659      0.000      -0.059      -0.032
# LSTAT         -0.0298      0.002    -12.134      0.000      -0.035      -0.025
# ==============================================================================
# Omnibus:                       30.699   Durbin-Watson:                   1.923
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               83.718
# Skew:                           0.372   Prob(JB):                     6.62e-19
# Kurtosis:                       5.263   Cond. No.                     2.09e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.09e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# **Observations:_____**
# * R squared is 0.769
# * NOX has a negative coefficient but it's the highest in absolute value
# * ZN, AGE, and INDUS are not statistically significant with α = 0.05 and their confidence interval contains 0
# * We see the warning that the condition numbr is large hinting at multicollinearity.

# %% [markdown]
# #### **Question 6:** Drop insignificant variables from the above model and create the regression model again. (2 Marks)

# %% [markdown]
# ### Examining the significance of the model
#
# It is not enough to fit a multiple regression model to the data, it is necessary to check whether all the regression coefficients are significant or not. Significance here means whether the population regression parameters are significantly different from zero.
#
# From the above it may be noted that the regression coefficients corresponding to ZN, AGE, and INDUS are not statistically significant at level α = 0.05. In other words, the regression coefficients corresponding to these three are not significantly different from 0 in the population. Hence, we will eliminate the three features and create a new model.

# %%
# create the model after dropping columns 'MEDV', 'MEDV_log', 'TAX', 'ZN', 'AGE', 'INDUS' from df dataframe
Y = df['MEDV_log']
X = df.drop(['MEDV', 'MEDV_log', 'TAX', 'ZN', 'AGE', 'INDUS'], axis=1) #write your code here
X = sm.add_constant(X)

#splitting the data in 70:30 ratio of train to test data
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.30 , random_state=1)

# here we are adding the intercept term
X_train = sm.add_constant(X_train)

# calling the OLS algorithm on the train features and target variable
model2 = sm.OLS(y_train, X_train)

# fitting the model
model2 = model2.fit()

# get the model summary
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               MEDV_log   R-squared:                       0.767
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     142.1
# Date:                Mon, 14 Feb 2022   Prob (F-statistic):          2.61e-104
# Time:                        23:06:56   Log-Likelihood:                 75.486
# No. Observations:                 354   AIC:                            -133.0
# Df Residuals:                     345   BIC:                            -98.15
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.6494      0.242     19.242      0.000       4.174       5.125
# CRIM          -0.0125      0.002     -7.349      0.000      -0.016      -0.009
# CHAS           0.1198      0.039      3.093      0.002       0.044       0.196
# NOX           -1.0562      0.168     -6.296      0.000      -1.386      -0.726
# RM             0.0589      0.020      2.928      0.004       0.019       0.098
# DIS           -0.0441      0.008     -5.561      0.000      -0.060      -0.028
# RAD            0.0078      0.002      3.890      0.000       0.004       0.012
# PTRATIO       -0.0485      0.006     -7.832      0.000      -0.061      -0.036
# LSTAT         -0.0293      0.002    -12.949      0.000      -0.034      -0.025
# ==============================================================================
# Omnibus:                       32.514   Durbin-Watson:                   1.925
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.354
# Skew:                           0.408   Prob(JB):                     1.07e-19
# Kurtosis:                       5.293   Cond. No.                         690.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# **Observations:**
# * We can see that the **R-squared value has decreased by 0.002**, since we have removed variables from the model, whereas the **adjusted R-squared value has increased by 0.001**, since we removed statistically insignificant variables only.

# %%
# Model Performance on test and train data
def model_perf(olsmodel, x_train, x_test):

    # In-sample Prediction
    y_pred_train = olsmodel.predict(x_train)
    y_observed_train = y_train

    # Prediction on test data
    y_pred_test = olsmodel.predict(x_test)
    y_observed_test = y_test

    print(
        pd.DataFrame(
            {
                "Data": ["Train", "Testdd"],
                "RMSE": [
                    rmse(y_pred_train, y_observed_train),
                    rmse(y_pred_test, y_observed_test),
                ],
                "MAE": [
                    mae(y_pred_train, y_observed_train),
                    mae(y_pred_test, y_observed_test),
                ],
                "MAPE": [
                    mape(y_pred_train, y_observed_train),
                    mape(y_pred_test, y_observed_test),
                ],
            }
        )
    )


# Checking model performance

model_perf(model1, X_train, X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/61/lkgw90991bq6gh25lnrhgr980000gn/T/ipykernel_5115/3038892119.py in <module>
#      33 # Checking model performance
#      34
# ---> 35 model_perf(model1, X_train, X_test)
#
# /var/folders/61/lkgw90991bq6gh25lnrhgr980000gn/T/ipykernel_5115/3038892119.py in model_perf(olsmodel, x_train, x_test)
#       3
#       4     # In-sample Prediction
# ----> 5     y_pred_train = olsmodel.predict(x_train)
#       6     y_observed_train = y_train
#       7
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py in predict(self, exog, transform, *args, **kwargs)
#    1097             exog = np.atleast_2d(exog)  # needed in count model shape[1]
#    1098
# -> 1099         predict_results = self.model.predict(self.params, exog, *args,
#    1100                                              **kwargs)
#    1101
#
# ~/opt/anaconda3/lib/python3.9/site-packages/statsmodels/regression/linear_model.py in predict(self, params, exog)
#     378             exog = self.exog
#     379
# --> 380         return np.dot(exog, params)
#     381
#     382     def get_distribution(self, params, scale, exog=None, dist_class=None):
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (354,9) and (12,) not aligned: 9 (dim 1) != 12 (dim 0)

# %% [markdown]
# Now, we will check the linear regression assumptions.

# %% [markdown]
# ### Check the below linear regression assumptions
#
# 1. **Mean of residuals should be 0**
# 2. **No Heteroscedasticity**
# 3. **Linearity of variables**
# 4. **Normality of error terms**

# %% [markdown]
# #### **Question 7:** Write the code to check the above linear regression assumptions and provide insights. (4 Marks)

# %% [markdown]
# #### Check for mean residuals

# %%
residuals = model2.resid # Residuals
residuals.mean()

# %% [markdown]
# **Observations:____**
# * the mean of the residuals is pretty much 0 so this assumption is satisfied

# %% [markdown]
# #### Check for homoscedasticity

# %% [markdown]
# * Homoscedasticity - If the residuals are symmetrically distributed across the regression line, then the data is said to homoscedastic.
#
# * Heteroscedasticity - If the residuals are not symmetrically distributed across the regression line, then the data is said to be heteroscedastic. In this case, the residuals can form a funnel shape or any other non-symmetrical shape.
#
# * We'll use `Goldfeldquandt Test` to test the following hypothesis with alpha = 0.05:
#
#     - Null hypothesis: Residuals are homoscedastic
#     - Alternate hypothesis: Residuals have heteroscedastic

# %%
from statsmodels.stats.diagnostic import het_white
from statsmodels.compat import lzip
import statsmodels.stats.api as sms

# %%
##### REMINDER TO double check! 

name = ["F statistic", "p-value"]
test = sms.het_goldfeldquandt(y_train,X_train)
lzip(name, test)

# %% [markdown]
# **Observations:____**
# * p-value > 0.05, so we fail to reject the null-hypothesis and we don't have enough evidence that residuals are heteroscedastic.

# %% [markdown]
# #### Linearity of variables
#
# It states that the predictor variables must have a linear relation with the dependent variable.
#
# To test the assumption, we'll plot residuals and fitted values on a plot and ensure that residuals do not form a strong pattern. They should be randomly and uniformly scattered on the x-axis.

# %%
# predicted values
fitted = model2.fittedvalues

# sns.set_style("whitegrid")
sns.residplot(x = fitted, y = residuals, color="lightblue", lowess=True) #write your code here
plt.xlabel("Fitted Values")
plt.ylabel("Residual")
plt.title("Residual PLOT")
plt.show()

# %% [markdown]
# **Observations:_____**
# * Residuals are fairly symmetrically distributed, tending to cluster towards the middle of the plot.
# * they’re clustered around 0 (but hthere are a few outliers above +.5 and -.5
# * However no clear patterns

# %% [markdown]
# #### Normality of error terms
# The residuals should be normally distributed.

# %%
# Plot histogram of residuals
#write your code here
sns.histplot(residuals,kde=True)

# %%
# Plot q-q plot of residuals
import pylab
import scipy.stats as stats

stats.probplot(residuals, dist="norm", plot=pylab)
plt.show()

# %% [markdown]
# **Observations:_____**
# * The. residuals do look to be normally distributed as shown by the 'kde' line on the residual histogram
# * The q-q plot corroborates that as the residuals doen't follow the line exactly but that the overall pattern matches fairly well

# %% [markdown]
# ### Check the performance of the model on the train and test data set

# %% [markdown]
# #### **Question 8:** Write your observations by comparing model performance of train and test dataset (2 Marks)

# %%
# RMSE
def rmse(predictions, targets):
    return np.sqrt(((targets - predictions) ** 2).mean())


# MAPE
def mape(predictions, targets):
    return np.mean(np.abs((targets - predictions)) / targets) * 100


# MAE
def mae(predictions, targets):
    return np.mean(np.abs((targets - predictions)))


# Model Performance on test and train data
def model_perf(olsmodel, x_train, x_test):

    # In-sample Prediction
    y_pred_train = olsmodel.predict(x_train)
    y_observed_train = y_train

    # Prediction on test data
    y_pred_test = olsmodel.predict(x_test)
    y_observed_test = y_test

    print(
        pd.DataFrame(
            {
                "Data": ["Train", "Test"],
                "RMSE": [
                    rmse(y_pred_train, y_observed_train),
                    rmse(y_pred_test, y_observed_test),
                ],
                "MAE": [
                    mae(y_pred_train, y_observed_train),
                    mae(y_pred_test, y_observed_test),
                ],
                "MAPE": [
                    mape(y_pred_train, y_observed_train),
                    mape(y_pred_test, y_observed_test),
                ],
            }
        )
    )


# Checking model performance
model_perf(model2, X_train, X_test)

# %% [markdown]
# **Observations:____**
# * The metrics are pretty similar on the Train and Test Data. All metrics are larger on the Test data but the difference is small suggesting the model is at a good baseline.
# * The MAPE difference is the largest

# %% [markdown]
# #### Apply cross validation to improve the model and evaluate it using different evaluation metrics

# %% [markdown]
# #### **Question 9:** Apply the cross validation technique to improve the model and evaluate it using different evaluation metrics. (1 Mark)

# %%
# import the required function

from sklearn.model_selection import cross_val_score

# build the regression model and cross-validate
linearregression = LinearRegression()                                                               


cv_Score11 = cross_val_score(linearregression, X_train, y_train, cv = 10)
cv_Score12 = cross_val_score(linearregression, X_train, y_train, cv = 10, 
                             scoring = 'neg_mean_squared_error')                                  


print("RSquared: %0.3f (+/- %0.3f)" % (cv_Score11.mean(), cv_Score11.std() * 2))
print("Mean Squared Error: %0.3f (+/- %0.3f)" % (-1*cv_Score12.mean(), cv_Score12.std() * 2))

# %%
model1.mse_resid

# %%
print("R-Squared:", linearregression.score(X_train,  y_train))

# %%
print("*********Training set Metrics**************")


se_train = (train[target] - mlr.predict(train[features_base]))**2
mse_train = se_trddain.mean()
print('MSE: ', mse_train)
print("********Validation set Metrics**************")
print("R-Squared:", mlr.score(validation[features_base], validation[target]))
se_val = (validation[target] - mlr.predict(validation[features_base]))**2
mse_val = se_val.mean()
print('MSE: ', mse_val)

# %% [markdown]
# **Observations**
# - The R-squared on the cross validation is 0.729, whereas on the training dataset it was 0.769
# - And the MSE on cross validation is 0.041, whereas on the training dataset it was 0.038

# %% [markdown]
# We may want to reiterate the model building process again with new features or better feature engineering to increase the R-squared and decrease the MSE on cross validation.

# %% [markdown]
# #### **Question 10:** Get model Coefficients in a pandas dataframe with column 'Feature' having all the features and column 'Coefs' with all the corresponding Coefs. Write the regression equation. (2 Marks)

# %%
model2.params.valuesdd

# %%
X.columns

# %%
d = {}
d['Feature']=model2.params.index.array[1:]
d['Coefs']=model2.params.values[1:]
coef = pd.DataFrame(data=d)
coef.set_index('Feature')

# %%
# Let us write the equation of the fit
Equation = "log(Price)=\n"
print(Equation, end='')

for i, row in coef.iterrows():
    cf = format(row['Coefs'], ".2f")
    print('\t(', cf, ') \t* ', row['Feature'], '+\n', end = ' ')
    #print('(', i, ') * ', row['Coefs'], '+',end = ' ')

#for i in range(len(coef)):
#    print('(', coef[i], ') * ', coef.index[i], '+', end = ' ')
# Out:
# log(Price)=
# 	( -0.01 ) 	*  CRIM +
#  	( 0.12 ) 	*  CHAS +
#  	( -1.06 ) 	*  NOX +
#  	( 0.06 ) 	*  RM +
#  	( -0.04 ) 	*  DIS +
#  	( 0.01 ) 	*  RAD +
#  	( -0.05 ) 	*  PTRATIO +
#  	( -0.03 ) 	*  LSTAT +

# %% [markdown]
# #### **Question 11:** Write the conclusions and business recommendations derived from the model. (5 Marks)

# %% [markdown]
# #### Conclusions and recommendations
#
# We performed univariate analysis to check the distribution of variables and bivariate analysis to check how attributes were correlated.
# We took the log of the dependent variable as the original appeared to be skewed, so we could proceed with our linear regression analysis.
# We started the model building the process with all the features
# We analyzed the model summary report
# Then we checked for different assumptions of linear regression,
# And we then fixed the model iteratively if any assumptions did not hold true
# Then we evaluated the model using different evaluation metrics
# Lastly below is the model equation:
#
# log(MEDV)=
# 	( -0.01 ) 	*  CRIM +
#  	( 0.12 ) 	*  CHAS +
#  	( -1.06 ) 	*  NOX +
#  	( 0.06 ) 	*  RM
#  	( -0.04 ) 	*  DIS +
#  	( 0.01 ) 	*  RAD +
#  	( -0.05 ) 	*  PTRATIO +
#  	( -0.03 ) 	*  LSTAT +
#
# Our interpratation is that
# NOX has a strong negative effect in property price. 1 unit change change in NOX will decrease the log of the price by -1.06. Pupil-teacher ratio has also a negative impact, which could be because people are willing to pay for living in areas where school zone districts have a high number of teachers, or also as perhap also suggested by the LSTAT coefficient, one could imagine that in lower income areas, there's more pupils than teachers, compared to more affluent ones.
#
# Houses can be priced by looking at the different attributes people value:
# Proximity to the Charles has a positive effect (increase) on the target variable, and as expected so has the number of rooms - with the above, this suggests that larger properties, closer to the river, in areas with less pollution, further from employment centers, and with higher ratio of teacher-pupils can be expected to have higher property values.
#
# If the business is a real estate agency flipping houses, we'd look to invest in houses that optimize for the positive attribute and minimize the negative ones.
